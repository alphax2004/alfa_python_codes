# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=20
#check if a>10 & a<50

num=a>10 and a<50
print(num)
#not meaning not present..false condition
print(not(num))
# Out:
# True
# False
