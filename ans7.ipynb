# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c=37
f=(c*9/5)+32
k=c+273.15

print("fahrenheit=",f)
print("kelvin=",k)
# Out:
# fahrenheit= 98.6
# kelvin= 310.15
