# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#take user input name age
name=input("enter your name ")
print(name)
age=input("enter your age ")
print(age)
# Out:
# enter your namealfa
# alfa
# enter your age20
# 20
