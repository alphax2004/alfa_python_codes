# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=40
b=30
print("addition",a+b)
print("subtraction",a-b)
print("multiplication",a*b)
print("division",a/b)
print("floor division",a//b)
print("modulus",a%b)
print("exponent",a**b)
# Out:
# addition 70
# subtraction 10
# multiplication 1200
# division 1.3333333333333333
# floor division 1
# modulus 10
# exponent 1152921504606846976000000000000000000000000000000
