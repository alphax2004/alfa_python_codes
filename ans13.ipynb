# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=5

#check if n %3 and n % 5

if n%3==0 and n%5==0:print("yes")
else:print("no")
# Out:
# no
