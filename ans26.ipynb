# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#union,intersection,difference of 2 sets

a={1,2,3,4,5}
b={4,5,6,7,8}
print(a)
print(b)
print(a|b)#union
print(a&b)#intersection
print(a-b)#difference
# Out:
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
