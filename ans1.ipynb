# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print hello world name and uni name....python e seperate bahbe c r moto endl lage na
#print diyei hoye jay
print("Hello World")

print("Sanjida Islam Alfa")

print("Ahsanullah University of Science and Technology")
# Out:
# Hello World
# Sanjida Islam Alfa
# Ahsanullah University of Science and Technology
