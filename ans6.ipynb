# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#swap variables

#store a,b
a=20
b=30
print("before swap",a," ",b)

a,b=b,a
print("after swap",a," ",b)
# Out:
# before swap 20   30
# after swap 30   20
