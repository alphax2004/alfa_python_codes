# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# factorial using loop
fn=6
factorial=1
for i in range(1,fn+1):
    factorial=factorial*i
print(factorial)
# Out:
# 720
