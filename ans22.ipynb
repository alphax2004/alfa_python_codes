# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# factorial using loop
r=5
for i in range(1,r+1):
  for j in range(i):print("*",end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
