# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#perimeter of rectangle
len=float(input("enter len"))
wid=float(input("enter wid"))
perimeter=2*(len+wid)
print("perimeter of rectangle",perimeter)
# Out:
# enter len3
# enter wid2
# perimeter of rectangle 10.0
