# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mixed_list=["Hello",43,2.3,True,(1,2,3)]
#list er moddhe shob type print korbo for loop diye
#list e comma diye shob data likha
for i in mixed_list:
    print(type(i))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'tuple'>
