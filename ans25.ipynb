# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#directory student info

student={"name":"alfa","age":20,"department":"cse"}
print(student["name"])
print(student["age"])
print(student["department"])
# Out:
# alfa
# 20
# cse
