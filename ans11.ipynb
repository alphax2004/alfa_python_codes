# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=5
#>,<,= compare
#prints in boolean
print("a==b",a==b)
print("a>b",a>b)
print("a<b",a<b)
# Out:
# a==b False
# a>b True
# a<b False
