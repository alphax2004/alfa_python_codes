# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ascii variable design '+'
#normal space diye korsi

print("++++++++")
print("+      +")
print("+      +")
print("+      +")
print("++++++++")
# Out:
# ++++++++
# +      +
# +      +
# +      +
# ++++++++
