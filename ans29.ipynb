# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#take user input 2 num and +,-,*
a=float(input("enter a "))
b=float(input("enter b "))
print(a+b," ",a-b," ",a*b)
# Out:
# enter a 2
# enter b 3
# 5.0   -1.0   6.0
