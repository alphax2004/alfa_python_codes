# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numtuple and show max,min sum
num_tuple=(1,2,3,4,5)
print(num_tuple)
print(max(num_tuple))
print(min(num_tuple))
print(sum(num_tuple))
# Out:
# (1, 2, 3, 4, 5)
# 5
# 1
# 15
