# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print grades using elif
m=60
if m>=90: cg="a+"
elif m>=70: cg="a"
elif m>=60: cg="b"
elif m>=50: cg="c"
elif m>=40: cg="d"
else: cg="f"
print(cg)
# Out:
# b
