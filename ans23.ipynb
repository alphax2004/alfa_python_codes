# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 5 fruits...add one and remove one
fruits=["apple","banana","mango","grape","orange"]
fruits.append("kiwi")
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'mango', 'grape', 'orange', 'kiwi']
