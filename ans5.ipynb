# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#store name
name="alfa"

#store age
age=20
#store height
height=4.9
#store bool status..boolean type
is_found=True
#print all

#datatype printof all
print(name,type(name))
print(age,type(age))
print(height,type(height))
print(is_found,type(is_found))
# Out:
# alfa <class 'str'>
# 20 <class 'int'>
# 4.9 <class 'float'>
# True <class 'bool'>
