# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print("python version",sys.version)
#import sys mane holo python built in system model ta import kore then print
#er moddhe sys.version likhle bujha jay je eta built in variable.....python r version print kore
# Out:
# python version 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
