# %% [markdown]
# <a href="https://colab.research.google.com/github/alphax2004/alfa_python_codes/blob/main/ans8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stringn1="123"
intnum=45
floatnum=9.8

#string float and integer conversion done with converted_int...
#then print the type

converted_int=int(stringn1)
print(converted_int)
print(type(converted_int))

converted_str=str(intnum)
print(converted_str)
print(type(converted_str))

converted_float=float(stringn1)
print(converted_float)
print(type(converted_float))
# Out:
# 123
# <class 'int'>
# 45
# <class 'str'>
# 123.0
# <class 'float'>
